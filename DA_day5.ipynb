# %% [markdown]
# <a href="https://colab.research.google.com/github/9490549112/22A81A0574-/blob/main/DA_day5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Random Fox API

# %%
import requests

# %%
page=requests.get("https://randomfox.ca/floof")#input

# %%
print(page.status_code)
# Out:
# 200

# %%
print(page.text)#output
# Out:
# {"image":"https:\/\/randomfox.ca\/images\/23.jpg","link":"https:\/\/randomfox.ca\/?i=23"}

# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'5000',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': 'cf0472be-b196-4a58-9e50-2a13228ef392',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
# Out:
# {'status': {'timestamp': '2024-02-16T09:46:40.663Z', 'error_code': 0, 'error_message': None, 'elapsed': 0, 'credit_count': 1, 'notice': None}, 'data': [{'id': 6792, 'name': 'jmirhugbrx', 'symbol': 'ap6yqbwoeia', 'slug': 'btojy330mms', 'cmc_rank': 6589, 'num_market_pairs': 74, 'circulating_supply': 3053, 'total_supply': 230, 'max_supply': 7795, 'infinite_supply': None, 'last_updated': '2024-02-16T09:46:40.663Z', 'date_added': '2024-02-16T09:46:40.663Z', 'tags': ['kkkfyzb17th', 'zu610ag4dx', 'hiyfarxa0gm', 'u7ookexq2sb', '9lzepx8setg', '6i1x2ifgf3v', 'e8hrc62mpyn', 'x014i6wga0i', 'njs7nt7nnkl', 'i37wo0574jn'], 'platform': None, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'quote': {'USD': {'price': 0.03989302937462824, 'volume_24h': 1915, 'volume_change_24h': 0.9082697423641604, 'percent_change_1h': 0.6657672468188929, 'percent_change_24h': 0.00849249995250001, 'percent_change_7d': 0.49737642290611395, 'market_cap': 0.49505067046815676, 'market_cap_domina
# ...

# %%
import pandas as pd
norm=pd.json_normalize(data['data'])

# %%
norm
# Out:
#      id         name       symbol         slug  cmc_rank  num_market_pairs  \
# 0  6792   jmirhugbrx  ap6yqbwoeia  btojy330mms      6589                74
# 1  8380  yp2k33hecdd  j86wj0byafm   ef7h5r3sdd      4588              2937
# 2    45  8feni72swsp   plcu321sex  d43283vo6wa       414               682
# 3  8523  y6qkz0740cg  ksubr04mz4g  7gzfg5nffgy      6063              4153
# 4  5276  26z2h5j7tgw  36utt8ubflf  1aliix9i9ul      9599              4452
# 5  3871   9b64v9a2px  fhdrsxqonxe  egdo41kregm      2281              5930
# 6  8511  o27ftenvksr  nd74khq9b38  j8stshcxn5n      9497              4097
# 7  3419  9jkv198zaqs  kly211g5btr  h9fm3nciorj      7568              1365
# 8  7785  29lo74b6oi5  adidw82s4vf   4lyshq6nvj      1589              1301
# 9  6690   guh3rcf1tb   q8qsu83f5j  duwmehx597r      6866              8997
#
#    circulating_supply  total_supply  max_supply infinite_supply  ...  \
# 0                3053           230        7795            None  ...
# ...
